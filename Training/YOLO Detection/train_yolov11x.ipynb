# %%
# !pip install roboflow
# !pip install -U ultralytics
# !pip install torchvision 
# !pip install pytorch

from roboflow import Roboflow
rf = Roboflow(api_key="66Oyn2UFQKFtsz1s4hs0")
project = rf.workspace("tulanelab").project("skin-lesion-detection-dnuq9")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# ...
#   Using cached pytorch-1.0.2.tar.gz (689 bytes)
#   Preparing metadata (setup.py) ... done
# ...
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pytorch)
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
import torch
import torchvision
# Load a pretrained YOLOv11x model
model = YOLO("yolo11x.pt")

# Train the model on your custom skin lesion dataset
train_results = model.train(
    data="/kaggle/working/Skin-Lesion-Detection-4/data.yaml",
    epochs=100,
    imgsz=640,
    project="/kaggle/working",     
    name="yolov11x_skin_lesions",  
    device=0 if torch.cuda.is_available() else "cpu",
)

# Evaluate the model
metrics = model.val()

# Run prediction on a sample image (change path if needed)
results = model("/kaggle/input/jpeg-isic2019-512x512/train/ISIC_0000010.jpg")
results[0].show()

# Export the trained model to ONNX format for deployment

onnx_path = model.export(format="onnx", dynamic=True, simplify=True, export_dir="/kaggle/working")

print("Model exported to:", onnx_path)
# Out:
# Ultralytics 8.3.145 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
